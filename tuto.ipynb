# %% [markdown]
# # Overview
#
# This notebook helps to create and validate a training set for the k-NN classifier described in the MediaPipe [Pose Classification](https://google.github.io/mediapipe/solutions/pose_classification.html) solution, it has greatly been inspired by it code example. Test it on an arbitrary video, export to a CSV and then use it to develop your own application.

# %% [markdown]
# # Step 0: Env setup

# %%
# !pip install pillow matplotlib numpy opencv-python tqdm requests mediapipe

# %%
#use this if the "Partie 2" folder is not your work directory.
# %cd Partie\ 2

# %% [markdown]
# # Codebase

# %% [markdown]
# ## Commons

# %%
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ### Comon folder architecture

# %%
import shutil
import os
from PoseClassification.utils import (
    show_image,
    create_images_folder_structure,
    create_docs_folder_structure,
    assert_images_in_folder,
    classify_pictures,
)
from PoseClassification.khouleuvre import sort_images

try:
    sort_images(
        os.getcwd(),
        "docs/images/test",
    )
except:
    print("Already parsed images")

# classify_pictures()
# Out:
# Already parsed images

# %%
# create_images_folder_structure()
# create_docs_folder_structure()
# assert_images_in_folder()

# %% [markdown]
# ## Pose embedding

# %%
from PoseClassification.pose_embedding import FullBodyPoseEmbedding

# %% [markdown]
# ## Pose classification

# %%
from PoseClassification.pose_classifier import PoseClassifier

# %% [markdown]
# ## Classification smoothing

# %%
from PoseClassification.utils import EMADictSmoothing

# %% [markdown]
# ## Repetition counter

# %%
from PoseClassification.utils import RepetitionCounter

# %% [markdown]
# ## Classification visualizer

# %%
from PoseClassification.visualize import PoseClassificationVisualizer

# %% [markdown]
# ## Bootstrap helper

# %%
from PoseClassification.bootstrap import BootstrapHelper

# %% [markdown]
# # Step 1: Build classifier

# %% [markdown]
# ## Image samples
#
# Locally create a folder named `fitness_poses_images_in` with image samples.
#
# Images should repesent terminal states of desired pose classes. I.e. if you want to classify push-up provide iamges for two classes: when person is up, and when person is down.
#
# There should be about a few hundred samples per class covering different camera angles, environment conditions, body shapes, and exercise variations to build a good classifier.
#
# Required structure of the images_in_folder:
# ```
# fitness_poses_images_in/
#   pushups_up/
#     image_001.jpg
#     image_002.jpg
#     ...
#   pushups_down/
#     image_001.jpg
#     image_002.jpg
#     ...
#   ...
# ```

# %% [markdown]
# ## Bootstrap images

# %%
# Required structure of the images_in_folder:
#
#   fitness_poses_images_in/
#     pushups_up/
#       image_001.jpg
#       image_002.jpg
#       ...
#     pushups_down
#
# /
#       image_001.jpg
#       image_002.jpg
#       ...
#     ...
cwd = os.getcwd()
bootstrap_images_in_folder = os.path.join(
    cwd, "test_results", "fitness_poses_images_in"
)

# Output folders for bootstrapped images and CSVs.
bootstrap_images_out_folder = os.path.join(
    cwd, "test_results", "fitness_poses_images_out"
)
bootstrap_csvs_out_folder = os.path.join(cwd, "test_results", "fitness_poses_csvs_out")

# %%
# Initialize helper.
bootstrap_helper = BootstrapHelper(
    images_in_folder=bootstrap_images_in_folder,
    images_out_folder=bootstrap_images_out_folder,
    csvs_out_folder=bootstrap_csvs_out_folder,
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/manulabricole/Documents/CDN/ACV/Partie_2/ACV_23_Part2.ipynb Cell 27 line 2
#       <a href='vscode-notebook-cell:/Users/manulabricole/Documents/CDN/ACV/Partie_2/ACV_23_Part2.ipynb#Y425sZmlsZQ%3D%3D?line=0'>1</a> # Initialize helper.
# ----> <a href='vscode-notebook-cell:/Users/manulabricole/Documents/CDN/ACV/Partie_2/ACV_23_Part2.ipynb#Y425sZmlsZQ%3D%3D?line=1'>2</a> bootstrap_helper = BootstrapHelper(
#       <a href='vscode-notebook-cell:/Users/manulabricole/Documents/CDN/ACV/Partie_2/ACV_23_Part2.ipynb#Y425sZmlsZQ%3D%3D?line=2'>3</a>     images_in_folder=bootstrap_images_in_folder,
#       <a href='vscode-notebook-cell:/Users/manulabricole/Documents/CDN/ACV/Partie_2/ACV_23_Part2.ipynb#Y425sZmlsZQ%3D%3D?line=3'>4</a>     images_out_folder=bootstrap_images_out_folder,
#       <a href='vscode-notebook-cell:/Users/manulabricole/Documents/CDN/ACV/Partie_2/ACV_23_Part2.ipynb#Y425sZmlsZQ%3D%3D?line=4'>5</a>     csvs_out_folder=bootstrap_csvs_out_folder,
#       <a href='vscode-notebook-cell:/Users/manulabricole/Documents/CDN/ACV/Partie_2/ACV_23_Part2.ipynb#Y425sZmlsZQ%3D%3D?line=5'>6</a> )
#
# File ~/Documents/CDN/ACV/Partie_2/PoseClassification/bootstrap.py:24, in BootstrapHelper.__init__(self, images_in_folder, images_out_folder, csvs_out_folder)
#      20 self._csvs_out_folder = csvs_out_folder
#      22 # Get list of pose classes and print image statistics.
#      23 self._pose_class_names = sorted(
# ---> 24     [n for n in os.listdir(self._images_in_folder) if not n.startswith(".")]
#      25 )
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/manulabricole/Documents/CDN/ACV/Partie_2/test_results/fitness_poses_images_in'

# %%
# Check how many pose classes and images for them are available.
bootstrap_helper.print_images_in_statistics()
# Out:
# Number of images per pose class:
#   pushups_down: 940
#   pushups_up: 1141

# %%
# Bootstrap all images.
# Set limit to some small number for debug.
bootstrap_helper.bootstrap(per_pose_class_limit=None)
# Out:
# Bootstrapping  pushups_down
#   0%|          | 0/940 [00:00<?, ?it/s]WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1699889822.955046       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#   0%|          | 1/940 [00:00<03:13,  4.85it/s]I0000 00:00:1699889823.090480       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   0%|          | 2/940 [00:00<02:25,  6.47it/s]I0000 00:00:1699889823.208680       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   0%|          | 3/940 [00:00<02:08,  7.31it/s]I0000 00:00:1699889823.323913       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   0%|          | 4/940 [00:00<02:00,  7.77it/s]I0000 00:00:1699889823.440848       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
# I0000 00:00:1699889823.538672       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   1%|          | 6/940 [00:00<01:50,  8.47it/s]I0000 00:00:1699889823.658357       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   1%|          | 7/940 [00:00<01:50,  8.42it/s]I0000 00:00:1699889823.778698       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   1%|          | 8/940 [00:01<01:50,  8.46it/s]I0000 00:00:1699889823.896895       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   1%|          | 9/940 [00:01<01:50,  8.40it/s]I0000 00:00:1699889824.016793       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   1%|          | 10/940 [00:01<01:50,  8.41it/s]I0000 00:00:1699889824.135047       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   1%|          | 11/940 [00:01<01:49,  8.48it/s]I0000 00:00:1699889824.250958       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   1%|▏         | 12/940 [00:01<01:48,  8.52it/s]I0000 00:00:1699889824.367194       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   1%|▏         | 13/940 [00:01<01:49,  8.50it/s]I0000 00:00:1699889824.484712       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   1%|▏         | 14/940 [00:01<01:49,  8.43it/s]I0000 00:00:1699889824.610837       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   2%|▏         | 15/940 [00:01<01:51,  8.30it/s]I0000 00:00:1699889824.732251       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   2%|▏         | 16/940 [00:01<01:51,  8.31it/s]I0000 00:00:1699889824.850461       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   2%|▏         | 17/940 [00:02<01:49,  8.45it/s]I0000 00:00:1699889824.964550       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   2%|▏         | 18/940 [00:02<01:48,  8.46it/s]I0000 00:00:1699889825.081877       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   2%|▏         | 19/940 [00:02<01:49,  8.44it/s]I0000 00:00:1699889825.201578       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   2%|▏         | 20/940 [00:02<01:48,  8.44it/s]I0000 00:00:1699889825.319608       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   2%|▏         | 21/940 [00:02<01:48,  8.50it/s]I0000 00:00:1699889825.436154       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   2%|▏         | 22/940 [00:02<01:47,  8.50it/s]I0000 00:00:1699889825.556323       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   2%|▏         | 23/940 [00:02<01:48,  8.42it/s]I0000 00:00:1699889825.674454       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   3%|▎         | 24/940 [00:02<01:48,  8.47it/s]I0000 00:00:1699889825.791035       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   3%|▎         | 25/940 [00:03<01:47,  8.49it/s]I0000 00:00:1699889825.908179       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   3%|▎         | 26/940 [00:03<01:47,  8.49it/s]I0000 00:00:1699889826.025947       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   3%|▎         | 27/940 [00:03<01:47,  8.52it/s]I0000 00:00:1699889826.142963       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   3%|▎         | 28/940 [00:03<01:47,  8.52it/s]I0000 00:00:1699889826.260056       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   3%|▎         | 29/940 [00:03<01:46,  8.56it/s]I0000 00:00:1699889826.376329       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   3%|▎         | 30/940 [00:03<01:47,  8.49it/s]I0000 00:00:1699889826.495911       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   3%|▎         | 31/940 [00:03<01:47,  8.47it/s]I0000 00:00:1699889826.615034       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   3%|▎         | 32/940 [00:03<01:46,  8.49it/s]I0000 00:00:1699889826.732323       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   4%|▎         | 33/940 [00:03<01:48,  8.33it/s]I0000 00:00:1699889826.856733       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   4%|▎         | 34/940 [00:04<01:47,  8.40it/s]I0000 00:00:1699889826.973938       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   4%|▎         | 35/940 [00:04<01:47,  8.41it/s]I0000 00:00:1699889827.091912       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   4%|▍         | 36/940 [00:04<01:47,  8.44it/s]I0000 00:00:1699889827.209374       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   4%|▍         | 37/940 [00:04<01:46,  8.49it/s]I0000 00:00:1699889827.325810       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   4%|▍         | 38/940 [00:04<01:45,  8.56it/s]I0000 00:00:1699889827.440489       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   4%|▍         | 39/940 [00:04<01:44,  8.60it/s]I0000 00:00:1699889827.556477       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   4%|▍         | 40/940 [00:04<01:45,  8.57it/s]I0000 00:00:1699889827.672374       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   4%|▍         | 41/940 [00:04<01:45,  8.55it/s]I0000 00:00:1699889827.790364       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   4%|▍         | 42/940 [00:05<01:44,  8.60it/s]I0000 00:00:1699889827.904747       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   5%|▍         | 43/940 [00:05<01:44,  8.57it/s]I0000 00:00:1699889828.023312       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   5%|▍         | 44/940 [00:05<01:44,  8.56it/s]I0000 00:00:1699889828.139461       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   5%|▍         | 45/940 [00:05<01:44,  8.60it/s]I0000 00:00:1699889828.255978       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
# I0000 00:00:1699889828.350562       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   5%|▌         | 47/940 [00:05<01:39,  8.96it/s]I0000 00:00:1699889828.467663       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   5%|▌         | 48/940 [00:05<01:40,  8.84it/s]I0000 00:00:1699889828.584879       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   5%|▌         | 49/940 [00:05<01:42,  8.69it/s]I0000 00:00:1699889828.707810       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   5%|▌         | 50/940 [00:05<01:43,  8.59it/s]I0000 00:00:1699889828.826463       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   5%|▌         | 51/940 [00:06<01:44,  8.53it/s]I0000 00:00:1699889828.944515       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   6%|▌         | 52/940 [00:06<01:43,  8.56it/s]I0000 00:00:1699889829.060724       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   6%|▌         | 53/940 [00:06<01:43,  8.54it/s]I0000 00:00:1699889829.179527       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   6%|▌         | 54/940 [00:06<01:44,  8.51it/s]I0000 00:00:1699889829.297923       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   6%|▌         | 55/940 [00:06<01:43,  8.55it/s]I0000 00:00:1699889829.414549       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   6%|▌         | 56/940 [00:06<01:44,  8.50it/s]I0000 00:00:1699889829.532558       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   6%|▌         | 57/940 [00:06<01:43,  8.50it/s]I0000 00:00:1699889829.649944       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   6%|▌         | 58/940 [00:06<01:43,  8.50it/s]I0000 00:00:1699889829.767457       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   6%|▋         | 59/940 [00:06<01:43,  8.52it/s]I0000 00:00:1699889829.884080       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   6%|▋         | 60/940 [00:07<01:42,  8.57it/s]I0000 00:00:1699889829.998775       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   6%|▋         | 61/940 [00:07<01:42,  8.57it/s]I0000 00:00:1699889830.115449       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   7%|▋         | 62/940 [00:07<01:42,  8.59it/s]I0000 00:00:1699889830.234378       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   7%|▋         | 63/940 [00:07<01:44,  8.39it/s]I0000 00:00:1699889830.356837       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   7%|▋         | 64/940 [00:07<01:44,  8.41it/s]I0000 00:00:1699889830.476027       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   7%|▋         | 65/940 [00:07<01:44,  8.37it/s]I0000 00:00:1699889830.598175       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   7%|▋         | 66/940 [00:07<01:44,  8.38it/s]I0000 00:00:1699889830.715619       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   7%|▋         | 67/940 [00:07<01:43,  8.44it/s]I0000 00:00:1699889830.831905       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   7%|▋         | 68/940 [00:08<01:43,  8.43it/s]I0000 00:00:1699889830.950526       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   7%|▋         | 69/940 [00:08<01:43,  8.43it/s]I0000 00:00:1699889831.072484       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   7%|▋         | 70/940 [00:08<01:43,  8.40it/s]I0000 00:00:1699889831.189431       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   8%|▊         | 71/940 [00:08<01:42,  8.45it/s]I0000 00:00:1699889831.306933       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   8%|▊         | 72/940 [00:08<01:42,  8.44it/s]I0000 00:00:1699889831.424627       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   8%|▊         | 73/940 [00:08<01:41,  8.52it/s]I0000 00:00:1699889831.539942       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   8%|▊         | 74/940 [00:08<01:41,  8.52it/s]I0000 00:00:1699889831.657082       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   8%|▊         | 75/940 [00:08<01:41,  8.49it/s]I0000 00:00:1699889831.775731       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   8%|▊         | 76/940 [00:09<01:41,  8.49it/s]I0000 00:00:1699889831.893603       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   8%|▊         | 77/940 [00:09<01:41,  8.52it/s]I0000 00:00:1699889832.010153       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   8%|▊         | 78/940 [00:09<01:41,  8.52it/s]I0000 00:00:1699889832.127171       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   8%|▊         | 79/940 [00:09<01:40,  8.54it/s]I0000 00:00:1699889832.244424       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   9%|▊         | 80/940 [00:09<01:40,  8.53it/s]I0000 00:00:1699889832.363540       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   9%|▊         | 81/940 [00:09<01:41,  8.43it/s]I0000 00:00:1699889832.483551       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   9%|▊         | 82/940 [00:09<01:41,  8.45it/s]I0000 00:00:1699889832.600928       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   9%|▉         | 83/940 [00:09<01:40,  8.50it/s]I0000 00:00:1699889832.717239       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   9%|▉         | 84/940 [00:09<01:40,  8.51it/s]I0000 00:00:1699889832.834085       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   9%|▉         | 85/940 [00:10<01:40,  8.50it/s]I0000 00:00:1699889832.951723       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   9%|▉         | 86/940 [00:10<01:39,  8.55it/s]I0000 00:00:1699889833.067907       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   9%|▉         | 87/940 [00:10<01:39,  8.54it/s]I0000 00:00:1699889833.188628       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   9%|▉         | 88/940 [00:10<01:40,  8.48it/s]I0000 00:00:1699889833.305870       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#   9%|▉         | 89/940 [00:10<01:40,  8.47it/s]I0000 00:00:1699889833.423613       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  10%|▉         | 90/940 [00:10<01:40,  8.49it/s]I0000 00:00:1699889833.540176       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  10%|▉         | 91/940 [00:10<01:39,  8.50it/s]I0000 00:00:1699889833.656947       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  10%|▉         | 92/940 [00:10<01:39,  8.49it/s]I0000 00:00:1699889833.775711       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  10%|▉         | 93/940 [00:11<01:40,  8.40it/s]I0000 00:00:1699889833.897498       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  10%|█         | 94/940 [00:11<01:40,  8.43it/s]I0000 00:00:1699889834.015329       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  10%|█         | 95/940 [00:11<01:39,  8.47it/s]I0000 00:00:1699889834.132844       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  10%|█         | 96/940 [00:11<01:39,  8.49it/s]I0000 00:00:1699889834.249047       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  10%|█         | 97/940 [00:11<01:40,  8.42it/s]I0000 00:00:1699889834.373003       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  10%|█         | 98/940 [00:11<01:39,  8.43it/s]I0000 00:00:1699889834.488917       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  11%|█         | 99/940 [00:11<01:39,  8.46it/s]I0000 00:00:1699889834.606080       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  11%|█         | 100/940 [00:11<01:39,  8.42it/s]I0000 00:00:1699889834.725257       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  11%|█         | 101/940 [00:11<01:39,  8.45it/s]I0000 00:00:1699889834.843316       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  11%|█         | 102/940 [00:12<01:38,  8.48it/s]I0000 00:00:1699889834.960214       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  11%|█         | 103/940 [00:12<01:38,  8.48it/s]I0000 00:00:1699889835.077852       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  11%|█         | 104/940 [00:12<01:39,  8.43it/s]I0000 00:00:1699889835.198149       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  11%|█         | 105/940 [00:12<01:39,  8.39it/s]I0000 00:00:1699889835.318616       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  11%|█▏        | 106/940 [00:12<01:38,  8.44it/s]I0000 00:00:1699889835.435164       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  11%|█▏        | 107/940 [00:12<01:38,  8.47it/s]I0000 00:00:1699889835.552512       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  11%|█▏        | 108/940 [00:12<01:37,  8.55it/s]I0000 00:00:1699889835.667138       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  12%|█▏        | 109/940 [00:12<01:37,  8.55it/s]I0000 00:00:1699889835.784227       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  12%|█▏        | 110/940 [00:13<01:38,  8.45it/s]I0000 00:00:1699889835.906470       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  12%|█▏        | 111/940 [00:13<01:37,  8.48it/s]I0000 00:00:1699889836.022785       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  12%|█▏        | 112/940 [00:13<01:37,  8.49it/s]I0000 00:00:1699889836.139390       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  12%|█▏        | 113/940 [00:13<01:37,  8.51it/s]I0000 00:00:1699889836.256441       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  12%|█▏        | 114/940 [00:13<01:36,  8.53it/s]I0000 00:00:1699889836.373116       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  12%|█▏        | 115/940 [00:13<01:36,  8.55it/s]I0000 00:00:1699889836.489177       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  12%|█▏        | 116/940 [00:13<01:35,  8.60it/s]I0000 00:00:1699889836.605600       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  12%|█▏        | 117/940 [00:13<01:36,  8.52it/s]I0000 00:00:1699889836.723986       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  13%|█▎        | 118/940 [00:13<01:36,  8.51it/s]I0000 00:00:1699889836.841907       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  13%|█▎        | 119/940 [00:14<01:35,  8.58it/s]I0000 00:00:1699889836.956774       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  13%|█▎        | 120/940 [00:14<01:36,  8.51it/s]I0000 00:00:1699889837.075905       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  13%|█▎        | 121/940 [00:14<01:35,  8.54it/s]I0000 00:00:1699889837.192178       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  13%|█▎        | 122/940 [00:14<01:35,  8.56it/s]I0000 00:00:1699889837.308007       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  13%|█▎        | 123/940 [00:14<01:35,  8.52it/s]I0000 00:00:1699889837.427650       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  13%|█▎        | 124/940 [00:14<01:36,  8.48it/s]I0000 00:00:1699889837.546360       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  13%|█▎        | 125/940 [00:14<01:36,  8.48it/s]I0000 00:00:1699889837.664860       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  13%|█▎        | 126/940 [00:14<01:36,  8.45it/s]I0000 00:00:1699889837.783763       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  14%|█▎        | 127/940 [00:15<01:36,  8.45it/s]I0000 00:00:1699889837.902037       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  14%|█▎        | 128/940 [00:15<01:35,  8.49it/s]I0000 00:00:1699889838.018711       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  14%|█▎        | 129/940 [00:15<01:35,  8.51it/s]I0000 00:00:1699889838.135676       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  14%|█▍        | 130/940 [00:15<01:34,  8.57it/s]I0000 00:00:1699889838.251296       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  14%|█▍        | 131/940 [00:15<01:35,  8.49it/s]I0000 00:00:1699889838.400431       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  14%|█▍        | 132/940 [00:15<01:41,  7.97it/s]I0000 00:00:1699889838.514823       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  14%|█▍        | 133/940 [00:15<01:39,  8.12it/s]I0000 00:00:1699889838.631047       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  14%|█▍        | 134/940 [00:15<01:40,  8.03it/s]I0000 00:00:1699889838.759832       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  14%|█▍        | 135/940 [00:15<01:38,  8.14it/s]I0000 00:00:1699889838.877660       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  14%|█▍        | 136/940 [00:16<01:37,  8.24it/s]I0000 00:00:1699889838.997917       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  15%|█▍        | 137/940 [00:16<01:37,  8.26it/s]I0000 00:00:1699889839.116441       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  15%|█▍        | 138/940 [00:16<01:35,  8.39it/s]I0000 00:00:1699889839.231539       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  15%|█▍        | 139/940 [00:16<01:34,  8.44it/s]I0000 00:00:1699889839.348427       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  15%|█▍        | 140/940 [00:16<01:34,  8.46it/s]I0000 00:00:1699889839.465125       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  15%|█▌        | 141/940 [00:16<01:33,  8.52it/s]I0000 00:00:1699889839.580447       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  15%|█▌        | 142/940 [00:16<01:33,  8.51it/s]I0000 00:00:1699889839.698686       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  15%|█▌        | 143/940 [00:16<01:33,  8.49it/s]I0000 00:00:1699889839.818092       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  15%|█▌        | 144/940 [00:17<01:32,  8.58it/s]I0000 00:00:1699889839.931250       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  15%|█▌        | 145/940 [00:17<01:33,  8.52it/s]I0000 00:00:1699889840.050262       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  16%|█▌        | 146/940 [00:17<01:32,  8.56it/s]I0000 00:00:1699889840.166139       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  16%|█▌        | 147/940 [00:17<01:32,  8.54it/s]I0000 00:00:1699889840.284231       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  16%|█▌        | 148/940 [00:17<01:33,  8.51it/s]I0000 00:00:1699889840.401705       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  16%|█▌        | 149/940 [00:17<01:32,  8.52it/s]I0000 00:00:1699889840.519734       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  16%|█▌        | 150/940 [00:17<01:33,  8.44it/s]I0000 00:00:1699889840.640274       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  16%|█▌        | 151/940 [00:17<01:32,  8.49it/s]I0000 00:00:1699889840.756206       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  16%|█▌        | 152/940 [00:17<01:32,  8.50it/s]I0000 00:00:1699889840.873827       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  16%|█▋        | 153/940 [00:18<01:32,  8.50it/s]I0000 00:00:1699889840.991086       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  16%|█▋        | 154/940 [00:18<01:31,  8.57it/s]I0000 00:00:1699889841.106168       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  16%|█▋        | 155/940 [00:18<01:31,  8.53it/s]I0000 00:00:1699889841.224002       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  17%|█▋        | 156/940 [00:18<01:31,  8.56it/s]I0000 00:00:1699889841.341448       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  17%|█▋        | 157/940 [00:18<01:31,  8.51it/s]I0000 00:00:1699889841.458971       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
# I0000 00:00:1699889841.555457       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  17%|█▋        | 159/940 [00:18<01:27,  8.92it/s]I0000 00:00:1699889841.673000       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
# I0000 00:00:1699889841.769055       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  17%|█▋        | 161/940 [00:18<01:22,  9.47it/s]I0000 00:00:1699889841.864165       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  17%|█▋        | 162/940 [00:19<01:24,  9.17it/s]I0000 00:00:1699889841.983422       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  17%|█▋        | 163/940 [00:19<01:26,  9.00it/s]I0000 00:00:1699889842.105262       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  17%|█▋        | 164/940 [00:19<01:27,  8.87it/s]I0000 00:00:1699889842.218184       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  18%|█▊        | 165/940 [00:19<01:28,  8.80it/s]I0000 00:00:1699889842.334915       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  18%|█▊        | 166/940 [00:19<01:29,  8.69it/s]I0000 00:00:1699889842.458231       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  18%|█▊        | 167/940 [00:19<01:30,  8.54it/s]I0000 00:00:1699889842.575986       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  18%|█▊        | 168/940 [00:19<01:30,  8.56it/s]I0000 00:00:1699889842.691823       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  18%|█▊        | 169/940 [00:19<01:30,  8.54it/s]I0000 00:00:1699889842.809625       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  18%|█▊        | 170/940 [00:20<01:29,  8.56it/s]I0000 00:00:1699889842.925999       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  18%|█▊        | 171/940 [00:20<01:31,  8.45it/s]I0000 00:00:1699889843.047432       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  18%|█▊        | 172/940 [00:20<01:30,  8.47it/s]I0000 00:00:1699889843.165497       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
# I0000 00:00:1699889843.264072       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  19%|█▊        | 174/940 [00:20<01:26,  8.81it/s]I0000 00:00:1699889843.381864       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  19%|█▊        | 175/940 [00:20<01:27,  8.76it/s]I0000 00:00:1699889843.497655       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  19%|█▊        | 176/940 [00:20<01:27,  8.69it/s]I0000 00:00:1699889843.615888       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  19%|█▉        | 177/940 [00:20<01:27,  8.69it/s]I0000 00:00:1699889843.731044       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  19%|█▉        | 178/940 [00:20<01:28,  8.60it/s]I0000 00:00:1699889843.849144       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
# I0000 00:00:1699889843.948360       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  19%|█▉        | 180/940 [00:21<01:22,  9.25it/s]I0000 00:00:1699889844.046221       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
# I0000 00:00:1699889844.141360       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  19%|█▉        | 182/940 [00:21<01:21,  9.29it/s]I0000 00:00:1699889844.258835       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  19%|█▉        | 183/940 [00:21<01:23,  9.10it/s]I0000 00:00:1699889844.376685       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  20%|█▉        | 184/940 [00:21<01:23,  9.01it/s]I0000 00:00:1699889844.494544       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  20%|█▉        | 185/940 [00:21<01:26,  8.76it/s]I0000 00:00:1699889844.614928       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  20%|█▉        | 186/940 [00:21<01:26,  8.70it/s]I0000 00:00:1699889844.731937       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  20%|█▉        | 187/940 [00:21<01:27,  8.63it/s]I0000 00:00:1699889844.851154       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  20%|██        | 188/940 [00:22<01:27,  8.58it/s]I0000 00:00:1699889844.969096       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  20%|██        | 189/940 [00:22<01:27,  8.55it/s]I0000 00:00:1699889845.086938       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  20%|██        | 190/940 [00:22<01:27,  8.55it/s]I0000 00:00:1699889845.206219       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  20%|██        | 191/940 [00:22<01:28,  8.49it/s]I0000 00:00:1699889845.324604       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  20%|██        | 192/940 [00:22<01:29,  8.39it/s]I0000 00:00:1699889845.446390       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  21%|██        | 193/940 [00:22<01:28,  8.40it/s]I0000 00:00:1699889845.564624       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
# I0000 00:00:1699889845.665153       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  21%|██        | 195/940 [00:22<01:21,  9.14it/s]I0000 00:00:1699889845.760720       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  21%|██        | 196/940 [00:22<01:22,  8.97it/s]I0000 00:00:1699889845.880329       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
# I0000 00:00:1699889845.977710       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  21%|██        | 198/940 [00:23<01:18,  9.47it/s]I0000 00:00:1699889846.073586       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  21%|██        | 199/940 [00:23<01:20,  9.19it/s]I0000 00:00:1699889846.192683       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
# I0000 00:00:1699889846.288914       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  21%|██▏       | 201/940 [00:23<01:19,  9.28it/s]I0000 00:00:1699889846.405270       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  21%|██▏       | 202/940 [00:23<01:21,  9.04it/s]I0000 00:00:1699889846.525399       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  22%|██▏       | 203/940 [00:23<01:23,  8.87it/s]I0000 00:00:1699889846.644708       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  22%|██▏       | 204/940 [00:23<01:24,  8.74it/s]I0000 00:00:1699889846.764226       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  22%|██▏       | 205/940 [00:23<01:24,  8.71it/s]I0000 00:00:1699889846.881617       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  22%|██▏       | 206/940 [00:24<01:25,  8.61it/s]I0000 00:00:1699889847.000301       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  22%|██▏       | 207/940 [00:24<01:25,  8.55it/s]I0000 00:00:1699889847.119681       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
# I0000 00:00:1699889847.217240       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  22%|██▏       | 209/940 [00:24<01:18,  9.27it/s]I0000 00:00:1699889847.314308       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  22%|██▏       | 210/940 [00:24<01:21,  9.01it/s]I0000 00:00:1699889847.433171       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  22%|██▏       | 211/940 [00:24<01:22,  8.86it/s]I0000 00:00:1699889847.551595       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  23%|██▎       | 212/940 [00:24<01:22,  8.79it/s]I0000 00:00:1699889847.667739       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  23%|██▎       | 213/940 [00:24<01:23,  8.68it/s]I0000 00:00:1699889847.789547       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  23%|██▎       | 214/940 [00:25<01:24,  8.58it/s]I0000 00:00:1699889847.906841       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  23%|██▎       | 215/940 [00:25<01:24,  8.60it/s]I0000 00:00:1699889848.021614       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  23%|██▎       | 216/940 [00:25<01:24,  8.60it/s]I0000 00:00:1699889848.139215       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  23%|██▎       | 217/940 [00:25<01:24,  8.52it/s]I0000 00:00:1699889848.258845       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  23%|██▎       | 218/940 [00:25<01:24,  8.55it/s]I0000 00:00:1699889848.374527       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  23%|██▎       | 219/940 [00:25<01:25,  8.46it/s]I0000 00:00:1699889848.497095       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  23%|██▎       | 220/940 [00:25<01:26,  8.37it/s]I0000 00:00:1699889848.618393       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  24%|██▎       | 221/940 [00:25<01:25,  8.42it/s]I0000 00:00:1699889848.735942       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  24%|██▎       | 222/940 [00:25<01:25,  8.42it/s]I0000 00:00:1699889848.854445       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  24%|██▎       | 223/940 [00:26<01:25,  8.41it/s]I0000 00:00:1699889848.973018       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  24%|██▍       | 224/940 [00:26<01:25,  8.41it/s]I0000 00:00:1699889849.092121       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  24%|██▍       | 225/940 [00:26<01:24,  8.46it/s]I0000 00:00:1699889849.208054       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  24%|██▍       | 226/940 [00:26<01:24,  8.43it/s]I0000 00:00:1699889849.330094       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  24%|██▍       | 227/940 [00:26<01:24,  8.43it/s]I0000 00:00:1699889849.447822       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  24%|██▍       | 228/940 [00:26<01:23,  8.48it/s]I0000 00:00:1699889849.564292       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  24%|██▍       | 229/940 [00:26<01:25,  8.36it/s]I0000 00:00:1699889849.689697       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  24%|██▍       | 230/940 [00:26<01:24,  8.38it/s]I0000 00:00:1699889849.807285       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  25%|██▍       | 231/940 [00:27<01:24,  8.37it/s]I0000 00:00:1699889849.924985       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  25%|██▍       | 232/940 [00:27<01:23,  8.45it/s]I0000 00:00:1699889850.041248       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  25%|██▍       | 233/940 [00:27<01:23,  8.51it/s]I0000 00:00:1699889850.155990       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  25%|██▍       | 234/940 [00:27<01:22,  8.58it/s]I0000 00:00:1699889850.272186       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  25%|██▌       | 235/940 [00:27<01:22,  8.53it/s]I0000 00:00:1699889850.391555       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  25%|██▌       | 236/940 [00:27<01:22,  8.50it/s]I0000 00:00:1699889850.508175       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  25%|██▌       | 237/940 [00:27<01:22,  8.55it/s]I0000 00:00:1699889850.623632       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  25%|██▌       | 238/940 [00:27<01:22,  8.56it/s]I0000 00:00:1699889850.740034       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  25%|██▌       | 239/940 [00:27<01:21,  8.57it/s]I0000 00:00:1699889850.856172       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  26%|██▌       | 240/940 [00:28<01:21,  8.58it/s]I0000 00:00:1699889850.972422       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  26%|██▌       | 241/940 [00:28<01:21,  8.61it/s]I0000 00:00:1699889851.089528       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  26%|██▌       | 242/940 [00:28<01:22,  8.50it/s]I0000 00:00:1699889851.208527       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  26%|██▌       | 243/940 [00:28<01:21,  8.54it/s]I0000 00:00:1699889851.325466       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  26%|██▌       | 244/940 [00:28<01:21,  8.51it/s]I0000 00:00:1699889851.443111       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  26%|██▌       | 245/940 [00:28<01:21,  8.48it/s]I0000 00:00:1699889851.563966       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  26%|██▌       | 246/940 [00:28<01:22,  8.45it/s]I0000 00:00:1699889851.682082       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  26%|██▋       | 247/940 [00:28<01:21,  8.50it/s]I0000 00:00:1699889851.797792       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  26%|██▋       | 248/940 [00:29<01:21,  8.52it/s]I0000 00:00:1699889851.914245       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  26%|██▋       | 249/940 [00:29<01:21,  8.49it/s]I0000 00:00:1699889852.032685       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  27%|██▋       | 250/940 [00:29<01:21,  8.45it/s]I0000 00:00:1699889852.155510       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  27%|██▋       | 251/940 [00:29<01:22,  8.39it/s]I0000 00:00:1699889852.274584       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  27%|██▋       | 252/940 [00:29<01:21,  8.45it/s]I0000 00:00:1699889852.390326       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  27%|██▋       | 253/940 [00:29<01:21,  8.46it/s]I0000 00:00:1699889852.507650       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  27%|██▋       | 254/940 [00:29<01:21,  8.46it/s]I0000 00:00:1699889852.625795       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  27%|██▋       | 255/940 [00:29<01:20,  8.53it/s]I0000 00:00:1699889852.741851       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  27%|██▋       | 256/940 [00:29<01:20,  8.54it/s]I0000 00:00:1699889852.857437       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  27%|██▋       | 257/940 [00:30<01:20,  8.50it/s]I0000 00:00:1699889852.976635       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  27%|██▋       | 258/940 [00:30<01:20,  8.49it/s]I0000 00:00:1699889853.097599       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  28%|██▊       | 259/940 [00:30<01:20,  8.51it/s]I0000 00:00:1699889853.214603       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  28%|██▊       | 260/940 [00:30<01:20,  8.48it/s]I0000 00:00:1699889853.330717       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  28%|██▊       | 261/940 [00:30<01:21,  8.30it/s]I0000 00:00:1699889853.458698       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  28%|██▊       | 262/940 [00:30<01:21,  8.32it/s]I0000 00:00:1699889853.576962       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  28%|██▊       | 263/940 [00:30<01:20,  8.43it/s]I0000 00:00:1699889853.691179       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  28%|██▊       | 264/940 [00:30<01:19,  8.49it/s]I0000 00:00:1699889853.807263       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  28%|██▊       | 265/940 [00:31<01:19,  8.50it/s]I0000 00:00:1699889853.925399       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  28%|██▊       | 266/940 [00:31<01:19,  8.52it/s]I0000 00:00:1699889854.042127       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  28%|██▊       | 267/940 [00:31<01:19,  8.51it/s]I0000 00:00:1699889854.159507       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  29%|██▊       | 268/940 [00:31<01:19,  8.45it/s]I0000 00:00:1699889854.280783       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  29%|██▊       | 269/940 [00:31<01:19,  8.46it/s]I0000 00:00:1699889854.397841       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  29%|██▊       | 270/940 [00:31<01:19,  8.44it/s]I0000 00:00:1699889854.516617       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  29%|██▉       | 271/940 [00:31<01:18,  8.52it/s]I0000 00:00:1699889854.631584       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  29%|██▉       | 272/940 [00:31<01:18,  8.53it/s]I0000 00:00:1699889854.748596       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  29%|██▉       | 273/940 [00:31<01:18,  8.51it/s]I0000 00:00:1699889854.867434       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  29%|██▉       | 274/940 [00:32<01:18,  8.46it/s]I0000 00:00:1699889854.989461       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  29%|██▉       | 275/940 [00:32<01:19,  8.37it/s]I0000 00:00:1699889855.108860       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  29%|██▉       | 276/940 [00:32<01:18,  8.42it/s]I0000 00:00:1699889855.226209       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  29%|██▉       | 277/940 [00:32<01:18,  8.48it/s]I0000 00:00:1699889855.343086       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  30%|██▉       | 278/940 [00:32<01:17,  8.49it/s]I0000 00:00:1699889855.459240       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  30%|██▉       | 279/940 [00:32<01:17,  8.48it/s]I0000 00:00:1699889855.580129       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  30%|██▉       | 280/940 [00:32<01:18,  8.44it/s]I0000 00:00:1699889855.697618       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  30%|██▉       | 281/940 [00:32<01:18,  8.43it/s]I0000 00:00:1699889855.816291       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  30%|███       | 282/940 [00:33<01:17,  8.48it/s]I0000 00:00:1699889855.932784       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  30%|███       | 283/940 [00:33<01:17,  8.49it/s]I0000 00:00:1699889856.050613       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  30%|███       | 284/940 [00:33<01:17,  8.51it/s]I0000 00:00:1699889856.166890       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  30%|███       | 285/940 [00:33<01:16,  8.54it/s]I0000 00:00:1699889856.283393       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  30%|███       | 286/940 [00:33<01:16,  8.52it/s]I0000 00:00:1699889856.401497       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  31%|███       | 287/940 [00:33<01:16,  8.56it/s]I0000 00:00:1699889856.517143       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  31%|███       | 288/940 [00:33<01:16,  8.57it/s]I0000 00:00:1699889856.633076       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  31%|███       | 289/940 [00:33<01:15,  8.59it/s]I0000 00:00:1699889856.750148       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  31%|███       | 290/940 [00:33<01:16,  8.49it/s]I0000 00:00:1699889856.870563       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  31%|███       | 291/940 [00:34<01:15,  8.57it/s]I0000 00:00:1699889856.985198       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  31%|███       | 292/940 [00:34<01:16,  8.50it/s]I0000 00:00:1699889857.105567       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  31%|███       | 293/940 [00:34<01:16,  8.49it/s]I0000 00:00:1699889857.226198       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  31%|███▏      | 294/940 [00:34<01:16,  8.49it/s]I0000 00:00:1699889857.339797       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  31%|███▏      | 295/940 [00:34<01:15,  8.51it/s]I0000 00:00:1699889857.456759       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  31%|███▏      | 296/940 [00:34<01:15,  8.54it/s]I0000 00:00:1699889857.572608       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
# ...
#  53%|█████▎    | 603/1141 [01:10<01:03,  8.44it/s]I0000 00:00:1699890004.121624       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  53%|█████▎    | 604/1141 [01:10<01:03,  8.47it/s]I0000 00:00:1699890004.239374       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  53%|█████▎    | 605/1141 [01:10<01:03,  8.46it/s]I0000 00:00:1699890004.359146       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  53%|█████▎    | 606/1141 [01:10<01:03,  8.44it/s]I0000 00:00:1699890004.476417       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  53%|█████▎    | 607/1141 [01:11<01:02,  8.49it/s]I0000 00:00:1699890004.592527       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  53%|█████▎    | 608/1141 [01:11<01:02,  8.57it/s]I0000 00:00:1699890004.709344       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  53%|█████▎    | 609/1141 [01:11<01:02,  8.52it/s]I0000 00:00:1699890004.826778       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  53%|█████▎    | 610/1141 [01:11<01:02,  8.51it/s]I0000 00:00:1699890004.943126       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  54%|█████▎    | 611/1141 [01:11<01:02,  8.45it/s]I0000 00:00:1699890005.064927       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  54%|█████▎    | 612/1141 [01:11<01:02,  8.45it/s]I0000 00:00:1699890005.181882       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  54%|█████▎    | 613/1141 [01:11<01:02,  8.42it/s]I0000 00:00:1699890005.302223       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  54%|█████▍    | 614/1141 [01:11<01:02,  8.43it/s]I0000 00:00:1699890005.419970       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  54%|█████▍    | 615/1141 [01:12<01:02,  8.45it/s]I0000 00:00:1699890005.538151       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  54%|█████▍    | 616/1141 [01:12<01:01,  8.47it/s]I0000 00:00:1699890005.655047       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  54%|█████▍    | 617/1141 [01:12<01:01,  8.50it/s]I0000 00:00:1699890005.773212       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  54%|█████▍    | 618/1141 [01:12<01:02,  8.40it/s]I0000 00:00:1699890005.895105       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  54%|█████▍    | 619/1141 [01:12<01:02,  8.36it/s]I0000 00:00:1699890006.017965       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  54%|█████▍    | 620/1141 [01:12<01:02,  8.34it/s]I0000 00:00:1699890006.135889       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  54%|█████▍    | 621/1141 [01:12<01:01,  8.40it/s]I0000 00:00:1699890006.253604       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  55%|█████▍    | 622/1141 [01:12<01:02,  8.35it/s]I0000 00:00:1699890006.374597       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  55%|█████▍    | 623/1141 [01:12<01:01,  8.41it/s]I0000 00:00:1699890006.492625       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  55%|█████▍    | 624/1141 [01:13<01:01,  8.38it/s]I0000 00:00:1699890006.611679       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  55%|█████▍    | 625/1141 [01:13<01:01,  8.33it/s]I0000 00:00:1699890006.732971       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  55%|█████▍    | 626/1141 [01:13<01:01,  8.41it/s]I0000 00:00:1699890006.852980       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  55%|█████▍    | 627/1141 [01:13<01:01,  8.31it/s]I0000 00:00:1699890006.973541       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  55%|█████▌    | 628/1141 [01:13<01:01,  8.36it/s]I0000 00:00:1699890007.093000       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  55%|█████▌    | 629/1141 [01:13<01:01,  8.31it/s]I0000 00:00:1699890007.213356       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  55%|█████▌    | 630/1141 [01:13<01:01,  8.32it/s]I0000 00:00:1699890007.332984       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  55%|█████▌    | 631/1141 [01:13<01:01,  8.34it/s]I0000 00:00:1699890007.452838       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  55%|█████▌    | 632/1141 [01:14<01:00,  8.39it/s]I0000 00:00:1699890007.570165       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  55%|█████▌    | 633/1141 [01:14<01:02,  8.12it/s]I0000 00:00:1699890007.704867       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  56%|█████▌    | 634/1141 [01:14<01:02,  8.13it/s]I0000 00:00:1699890007.825253       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  56%|█████▌    | 635/1141 [01:14<01:02,  8.11it/s]I0000 00:00:1699890007.952061       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  56%|█████▌    | 636/1141 [01:14<01:02,  8.02it/s]I0000 00:00:1699890008.077320       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  56%|█████▌    | 637/1141 [01:14<01:02,  8.02it/s]I0000 00:00:1699890008.202158       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  56%|█████▌    | 638/1141 [01:14<01:02,  8.10it/s]I0000 00:00:1699890008.322688       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  56%|█████▌    | 639/1141 [01:14<01:01,  8.16it/s]I0000 00:00:1699890008.444072       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  56%|█████▌    | 640/1141 [01:15<01:01,  8.15it/s]I0000 00:00:1699890008.572083       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  56%|█████▌    | 641/1141 [01:15<01:01,  8.08it/s]I0000 00:00:1699890008.693592       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  56%|█████▋    | 642/1141 [01:15<01:01,  8.14it/s]I0000 00:00:1699890008.813636       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  56%|█████▋    | 643/1141 [01:15<01:02,  7.95it/s]I0000 00:00:1699890008.946718       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  56%|█████▋    | 644/1141 [01:15<01:02,  8.01it/s]I0000 00:00:1699890009.068184       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  57%|█████▋    | 645/1141 [01:15<01:01,  8.12it/s]I0000 00:00:1699890009.187656       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  57%|█████▋    | 646/1141 [01:15<01:01,  8.07it/s]I0000 00:00:1699890009.313449       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  57%|█████▋    | 647/1141 [01:15<01:00,  8.16it/s]I0000 00:00:1699890009.434070       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  57%|█████▋    | 648/1141 [01:16<01:00,  8.16it/s]I0000 00:00:1699890009.586594       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  57%|█████▋    | 649/1141 [01:16<01:04,  7.60it/s]I0000 00:00:1699890009.707266       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  57%|█████▋    | 650/1141 [01:16<01:02,  7.82it/s]I0000 00:00:1699890009.827323       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  57%|█████▋    | 651/1141 [01:16<01:01,  7.95it/s]I0000 00:00:1699890009.947681       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  57%|█████▋    | 652/1141 [01:16<01:00,  8.05it/s]I0000 00:00:1699890010.069133       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  57%|█████▋    | 653/1141 [01:16<01:00,  8.06it/s]I0000 00:00:1699890010.193041       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  57%|█████▋    | 654/1141 [01:16<01:00,  8.02it/s]I0000 00:00:1699890010.322078       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  57%|█████▋    | 655/1141 [01:16<01:01,  7.96it/s]I0000 00:00:1699890010.446163       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  57%|█████▋    | 656/1141 [01:17<01:00,  8.07it/s]I0000 00:00:1699890010.567642       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  58%|█████▊    | 657/1141 [01:17<00:59,  8.10it/s]I0000 00:00:1699890010.687762       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  58%|█████▊    | 658/1141 [01:17<00:58,  8.23it/s]I0000 00:00:1699890010.805396       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  58%|█████▊    | 659/1141 [01:17<00:58,  8.28it/s]I0000 00:00:1699890010.925577       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  58%|█████▊    | 660/1141 [01:17<00:57,  8.30it/s]I0000 00:00:1699890011.044413       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  58%|█████▊    | 661/1141 [01:17<00:57,  8.39it/s]I0000 00:00:1699890011.160556       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  58%|█████▊    | 662/1141 [01:17<00:57,  8.38it/s]I0000 00:00:1699890011.279735       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  58%|█████▊    | 663/1141 [01:17<00:57,  8.35it/s]I0000 00:00:1699890011.401658       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  58%|█████▊    | 664/1141 [01:18<00:57,  8.23it/s]I0000 00:00:1699890011.527530       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  58%|█████▊    | 665/1141 [01:18<00:57,  8.25it/s]I0000 00:00:1699890011.646870       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  58%|█████▊    | 666/1141 [01:18<00:56,  8.35it/s]I0000 00:00:1699890011.763316       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  58%|█████▊    | 667/1141 [01:18<00:56,  8.34it/s]I0000 00:00:1699890011.883571       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  59%|█████▊    | 668/1141 [01:18<00:57,  8.26it/s]I0000 00:00:1699890012.008958       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  59%|█████▊    | 669/1141 [01:18<00:57,  8.25it/s]I0000 00:00:1699890012.130047       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  59%|█████▊    | 670/1141 [01:18<00:57,  8.24it/s]I0000 00:00:1699890012.251774       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  59%|█████▉    | 671/1141 [01:18<00:57,  8.24it/s]I0000 00:00:1699890012.372163       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  59%|█████▉    | 672/1141 [01:18<00:56,  8.27it/s]I0000 00:00:1699890012.493711       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  59%|█████▉    | 673/1141 [01:19<00:56,  8.25it/s]I0000 00:00:1699890012.613891       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  59%|█████▉    | 674/1141 [01:19<00:56,  8.33it/s]I0000 00:00:1699890012.732303       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  59%|█████▉    | 675/1141 [01:19<00:55,  8.32it/s]I0000 00:00:1699890012.851947       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  59%|█████▉    | 676/1141 [01:19<00:55,  8.36it/s]I0000 00:00:1699890012.970232       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  59%|█████▉    | 677/1141 [01:19<00:56,  8.27it/s]I0000 00:00:1699890013.094210       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  59%|█████▉    | 678/1141 [01:19<00:55,  8.30it/s]I0000 00:00:1699890013.213416       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  60%|█████▉    | 679/1141 [01:19<00:55,  8.29it/s]I0000 00:00:1699890013.335475       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
#  60%|█████▉    | 680/1141 [01:19<00:54,  8.50it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/manulabricole/Documents/CDN/ACV/Partie_2/ACV_23_Part2.ipynb Cell 29 line 3
#       <a href='vscode-notebook-cell:/Users/manulabricole/Documents/CDN/ACV/Partie_2/ACV_23_Part2.ipynb#Y430sZmlsZQ%3D%3D?line=0'>1</a> # Bootstrap all images.
#       <a href='vscode-notebook-cell:/Users/manulabricole/Documents/CDN/ACV/Partie_2/ACV_23_Part2.ipynb#Y430sZmlsZQ%3D%3D?line=1'>2</a> # Set limit to some small number for debug.
# ----> <a href='vscode-notebook-cell:/Users/manulabricole/Documents/CDN/ACV/Partie_2/ACV_23_Part2.ipynb#Y430sZmlsZQ%3D%3D?line=2'>3</a> bootstrap_helper.bootstrap(per_pose_class_limit=None)
#
# File ~/Documents/CDN/ACV/Partie_2/PoseClassification/bootstrap.py:82, in BootstrapHelper.bootstrap(self, per_pose_class_limit)
#      78 input_frame = cv2.cvtColor(input_frame, cv2.COLOR_BGR2RGB)
#      80 # Initialize fresh pose tracker and run it.
#      81 # with mp_pose.Pose(upper_body_only=False) as pose_tracker:
# ---> 82 with mp_pose.Pose() as pose_tracker:
#      83     result = pose_tracker.process(image=input_frame)
#      84     pose_landmarks = result.pose_landmarks
#
# File ~/.pyenv/versions/3.11.0/envs/acv_2/lib/python3.11/site-packages/mediapipe/python/solutions/pose.py:146, in Pose.__init__(self, static_image_mode, model_complexity, smooth_landmarks, enable_segmentation, smooth_segmentation, min_detection_confidence, min_tracking_confidence)
#     122 """Initializes a MediaPipe Pose object.
#     123
#     124 Args:
#    (...)
#     143     https://solutions.mediapipe.dev/pose#min_tracking_confidence.
#     144 """
#     145 _download_oss_pose_landmark_model(model_complexity)
# --> 146 super().__init__(
#     147     binary_graph_path=_BINARYPB_FILE_PATH,
#     148     side_inputs={
#     149         'model_complexity': model_complexity,
#     150         'smooth_landmarks': smooth_landmarks and not static_image_mode,
#     151         'enable_segmentation': enable_segmentation,
#     152         'smooth_segmentation':
#     153             smooth_segmentation and not static_image_mode,
#     154         'use_prev_landmarks': not static_image_mode,
#     155     },
#     156     calculator_params={
#     157         'posedetectioncpu__TensorsToDetectionsCalculator.min_score_thresh':
#     158             min_detection_confidence,
#     159         'poselandmarkbyroicpu__tensorstoposelandmarksandsegmentation__ThresholdingCalculator.threshold':
#     160             min_tracking_confidence,
#     161     },
#     162     outputs=['pose_landmarks', 'pose_world_landmarks', 'segmentation_mask'])
#
# File ~/.pyenv/versions/3.11.0/envs/acv_2/lib/python3.11/site-packages/mediapipe/python/solution_base.py:271, in SolutionBase.__init__(self, binary_graph_path, graph_config, calculator_params, graph_options, side_inputs, outputs, stream_type_hints)
#     269 validated_graph = validated_graph_config.ValidatedGraphConfig()
#     270 if binary_graph_path:
# --> 271   validated_graph.initialize(
#     272       binary_graph_path=os.path.join(root_path, binary_graph_path))
#     273 else:
#     274   validated_graph.initialize(graph_config=graph_config)
#
# KeyboardInterrupt:

# %%
# Check how many images were bootstrapped.
bootstrap_helper.print_images_out_statistics()

# %%
# After initial bootstrapping images without detected poses were still saved in
# the folderd (but not in the CSVs) for debug purpose. Let's remove them.
bootstrap_helper.align_images_and_csvs(print_removed_items=True)
bootstrap_helper.print_images_out_statistics()

# %% [markdown]
# ## Manual filtration
#
# Please manually verify predictions and remove samples (images) that has wrong pose prediction. Check as if you were asked to classify pose just from predicted landmarks. If you can't - remove it.
#
# Align CSVs and image folders once you are done.

# %%
# Align CSVs with filtered images.
bootstrap_helper.align_images_and_csvs(print_removed_items=True)
bootstrap_helper.print_images_out_statistics()

# %% [markdown]
# ## Automatic filtration
#
# Classify each sample against database of all other samples and check if it gets in the same class as annotated after classification.
#
# There can be two reasons for the outliers:
#
#   * **Wrong pose prediction**: In this case remove such outliers.
#
#   * **Wrong classification** (i.e. pose is predicted correctly and you aggree with original pose class assigned to the sample): In this case sample is from the underrepresented group (e.g. unusual angle or just very few samples). Add more similar samples and run bootstrapping from the very beginning.
#
# Even if you just removed some samples it makes sence to re-run automatic filtration one more time as database of poses has changed.
#
# **Important!!** Check that you are using the same parameters when classifying whole videos later.

# %%
# Find outliers.

# Transforms pose landmarks into embedding.
pose_embedder = FullBodyPoseEmbedding()

# Classifies give pose against database of poses.
pose_classifier = PoseClassifier(
    pose_samples_folder=bootstrap_csvs_out_folder,
    pose_embedder=pose_embedder,
    top_n_by_max_distance=30,
    top_n_by_mean_distance=10)

outliers = pose_classifier.find_pose_sample_outliers()
print('Number of outliers: ', len(outliers))

# %%
# Analyze outliers.
bootstrap_helper.analyze_outliers(outliers)

# %%
# Remove all outliers (if you don't want to manually pick).
bootstrap_helper.remove_outliers(outliers)

# %%
# Align CSVs with images after removing outliers.
bootstrap_helper.align_images_and_csvs(print_removed_items=False)
bootstrap_helper.print_images_out_statistics()

# %% [markdown]
# ## Dump classifier data to CSV
#
# Dump filtered poses to CSV and download it.
#
# *Opt. : Please check this [guide](https://developers.google.com/ml-kit/vision/pose-detection/classifying-poses#4_integrate_with_the_ml_kit_quickstart_app) on how to use this CSV in the ML Kit sample app.*

# %%
import csv
import os
import numpy as np


def dump_for_the_app():
    pose_samples_folder = "fitness_poses_csvs_out"
    pose_samples_csv_path = "fitness_poses_csvs_out.csv"
    file_extension = "csv"
    file_separator = ","

    # Each file in the folder represents one pose class.
    file_names = [
        name
        for name in os.listdir(pose_samples_folder)
        if name.endswith(file_extension)
    ]

    with open(pose_samples_csv_path, "w") as csv_out:
        csv_out_writer = csv.writer(
            csv_out, delimiter=file_separator, quoting=csv.QUOTE_MINIMAL
        )
        for file_name in file_names:
            # Use file name as pose class name.
            class_name = file_name[: -(len(file_extension) + 1)]

            # One file line: `sample_00001,x1,y1,x2,y2,....`.
            with open(os.path.join(pose_samples_folder, file_name)) as csv_in:
                csv_in_reader = csv.reader(csv_in, delimiter=file_separator)
                for row in csv_in_reader:
                    row.insert(1, class_name)
                    csv_out_writer.writerow(row)

    # files.download(pose_samples_csv_path)


dump_for_the_app()

# %% [markdown]
# # Step 2: Classification
#
# **Important!!** Check that you are using the same classification parameters as while building classifier.

# %%
# Specify your video name and target pose class to count the repetitions.
video_folder = os.path.join(cwd, "docs", "videos", "correct_sequence")

for file in os.listdir(video_folder):
    if file.endswith(".mp4"):
        # Replace spaces with underscores in the filename
        new_filename = file.replace(" ", "_")

        if new_filename != file:  # Check if a rename is necessary
            # Define the current and new file paths
            old_video_path = os.path.join(video_folder, file)
            new_video_path = os.path.join(video_folder, new_filename)

            # Rename the file
            os.rename(old_video_path, new_video_path)

files = os.listdir(video_folder)
filepath = os.path.join(video_folder, files[5])

# %%
video_path = os.path.join(os.getcwd(), "pushups-sample-out.mp4")
print(video_path)
class_name = "pushups_up"
out_video_path = video_path
# Out:
# /Users/manulabricole/Documents/CDN/ACV/Partie_2/pushups-sample-out.mp4

# %%
# Open the video.
import cv2

video_cap = cv2.VideoCapture(video_path)

# Get some video parameters to generate output video with classificaiton.
video_n_frames = video_cap.get(cv2.CAP_PROP_FRAME_COUNT)
video_fps = video_cap.get(cv2.CAP_PROP_FPS)
video_width = int(video_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
video_height = int(video_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

print(f"video_n_frames: {video_n_frames}")
print(f"video_fps: {video_fps}")
print(f"video_width: {video_width}")
print(f"video_height: {video_height}")
# Out:
# video_n_frames: 3.0
# video_fps: 25.0
# video_width: 640
# video_height: 360

# %%
# Initialize tracker, classifier and counter.
# Do that before every video as all of them have state.
from mediapipe.python.solutions import pose as mp_pose


# Folder with pose class CSVs. That should be the same folder you used while
# building classifier to output CSVs.
pose_samples_folder = 'fitness_poses_csvs_out'

# Initialize tracker.
pose_tracker = mp_pose.Pose()

# Initialize embedder.
pose_embedder = FullBodyPoseEmbedding()

# Initialize classifier.
# Check that you are using the same parameters as during bootstrapping.
pose_classifier = PoseClassifier(
    pose_samples_folder=pose_samples_folder,
    pose_embedder=pose_embedder,
    top_n_by_max_distance=30,
    top_n_by_mean_distance=10)

# # Uncomment to validate target poses used by classifier and find outliers.
outliers = pose_classifier.find_pose_sample_outliers()
print('Number of pose sample outliers (consider removing them): ', len(outliers))

# Initialize EMA smoothing.
pose_classification_filter = EMADictSmoothing(
    window_size=10,
    alpha=0.2)

# Initialize counter.
repetition_counter = RepetitionCounter(
    class_name=class_name,
    enter_threshold=6,
    exit_threshold=4)

# Initialize renderer.
pose_classification_visualizer = PoseClassificationVisualizer(
    class_name=class_name,
    plot_x_max=video_n_frames,
    # Graphic looks nicer if it's the same as `top_n_by_mean_distance`.
    plot_y_max=10)
# Out:
# I0000 00:00:1699891196.990631       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 86), renderer: Apple M1 Max
# Number of pose sample outliers (consider removing them):  62

# %%
# Run classification on a video.
import os
import tqdm

from mediapipe.python.solutions import drawing_utils as mp_drawing


# Open output video.
out_video = cv2.VideoWriter(out_video_path, cv2.VideoWriter_fourcc(*'mp4v'), video_fps, (video_width, video_height))

frame_idx = 0
output_frame = None
with tqdm.tqdm(total=video_n_frames, position=0, leave=True) as pbar:
  while True:
    # Get next frame of the video.
    success, input_frame = video_cap.read()
    if not success:
      print("unable to read input video frame, breaking!")
      break

    # Run pose tracker.
    input_frame = cv2.cvtColor(input_frame, cv2.COLOR_BGR2RGB)
    result = pose_tracker.process(image=input_frame)
    pose_landmarks = result.pose_landmarks

    # Draw pose prediction.
    output_frame = input_frame.copy()
    if pose_landmarks is not None:
      mp_drawing.draw_landmarks(
          image=output_frame,
          landmark_list=pose_landmarks,
          connections=mp_pose.POSE_CONNECTIONS)
    
    if pose_landmarks is not None:
      # Get landmarks.
      frame_height, frame_width = output_frame.shape[0], output_frame.shape[1]
      pose_landmarks = np.array([[lmk.x * frame_width, lmk.y * frame_height, lmk.z * frame_width]
                                 for lmk in pose_landmarks.landmark], dtype=np.float32)
      assert pose_landmarks.shape == (33, 3), 'Unexpected landmarks shape: {}'.format(pose_landmarks.shape)

      # Classify the pose on the current frame.
      pose_classification = pose_classifier(pose_landmarks)

      # Smooth classification using EMA.
      pose_classification_filtered = pose_classification_filter(pose_classification)

      # Count repetitions.
      repetitions_count = repetition_counter(pose_classification_filtered)
    else:
      # No pose => no classification on current frame.
      pose_classification = None

      # Still add empty classification to the filter to maintaing correct
      # smoothing for future frames.
      pose_classification_filtered = pose_classification_filter(dict())
      pose_classification_filtered = None

      # Don't update the counter presuming that person is 'frozen'. Just
      # take the latest repetitions count.
      repetitions_count = repetition_counter.n_repeats

    # Draw classification plot and repetition counter.
    output_frame = pose_classification_visualizer(
        frame=output_frame,
        pose_classification=pose_classification,
        pose_classification_filtered=pose_classification_filtered,
        repetitions_count=repetitions_count)

    # Save the output frame.
    out_video.write(cv2.cvtColor(np.array(output_frame), cv2.COLOR_RGB2BGR))

    # Show intermediate frames of the video to track progress.
    if frame_idx % 50 == 0:
      show_image(output_frame)

    frame_idx += 1
    pbar.update()

# Close output video.
out_video.release()

# Release MediaPipe resources.
# pose_tracker.close()

# Show the last frame of the video.
if output_frame is not None:
  show_image(output_frame)
# Out:
#   0%|          | 0/3.0 [00:00<?, ?it/s]
# unable to read input video frame, breaking!
